# %%
# Navigate to the project directory
# !git clone https://github.com/RoshanVarghese/TextToImage.git
# %cd TextToImage/
# Install dependencies
#!pip install diffusers torch transformers peft gradio accelerate

# Run the app
# !python app.py
# Out:
# Cloning into 'TextToImage'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 46 (delta 22), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (46/46), 96.26 KiB | 1.82 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# /content/TextToImage
# 2025-08-17 16:27:54.698910: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755448074.719697    1672 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
